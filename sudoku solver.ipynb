# %%
rows = 'ABCDEFGHI'
cols = '123456789'

grid = '4.....8.5.3..........7......2.....6.....8.4......1.......6.3.7.5..2.....1.4......'

# %%
def cross(a, b):
    return [s+t for s in a for t in b]

# %%
boxes = cross(rows, cols)
boxes
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'A6',
#  'A7',
#  'A8',
#  'A9',
#  'B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'B7',
#  'B8',
#  'B9',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'C6',
#  'C7',
#  'C8',
#  'C9',
#  'D1',
#  'D2',
#  'D3',
#  'D4',
#  'D5',
#  'D6',
#  'D7',
#  'D8',
#  'D9',
#  'E1',
#  'E2',
#  'E3',
#  'E4',
#  'E5',
#  'E6',
#  'E7',
#  'E8',
#  'E9',
#  'F1',
#  'F2',
#  'F3',
#  'F4',
#  'F5',
#  'F6',
#  'F7',
#  'F8',
#  'F9',
#  'G1',
#  'G2',
#  'G3',
#  'G4',
#  'G5',
#  'G6',
#  'G7',
#  'G8',
#  'G9',
#  'H1',
#  'H2',
#  'H3',
#  'H4',
#  'H5',
#  'H6',
#  'H7',
#  'H8',
#  'H9',
#  'I1',
#  'I2',
#  'I3',
#  'I4',
#  'I5',
#  'I6',
#  'I7',
#  'I8',
#  'I9']

# %%
row_units = [cross(r, cols) for r in rows]
print("row units: ", row_units)
column_units = [cross(rows, c) for c in cols]
print("column units: ", column_units)
square_units = [cross(rs, cs) for rs in ('ABC','DEF','GHI') for cs in ('123','456','789')]
print("square units: ", square_units)
unitlist = row_units + column_units + square_units

units = dict((s, [u for u in unitlist if s in u]) for s in boxes)
peers = dict((s, set(sum(units[s],[]))-set([s])) for s in boxes)
# Out:
# row units:  [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9'], ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9'], ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'], ['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9'], ['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9'], ['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9'], ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9'], ['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9'], ['I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9']]
# column units:  [['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'I1'], ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2', 'I2'], ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3', 'I3'], ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4', 'I4'], ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5', 'I5'], ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6', 'I6'], ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7', 'I7'], ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8', 'I8'], ['A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9', 'I9']]
# square units:  [['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3'], ['A4', 'A5', 'A6', 'B4', 'B5', 'B6', 'C4', 'C5', 'C6'], ['A7', 'A8', 'A9', 'B7', 'B8', 'B9', 'C7', 'C8', 'C9'], ['D1', 'D2', 'D3', 'E1', 'E2', 'E3', 'F1', 'F2', 'F3'], ['D4', 'D5', 'D6', 'E4', 'E5', 'E6', 'F4', 'F5', 'F6'], ['D7', 'D8', 'D9', 'E7', 'E8', 'E9', 'F7', 'F8', 'F9'], ['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3'], ['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6'], ['G7', 'G8', 'G9', 'H7', 'H8', 'H9', 'I7', 'I8', 'I9']]

# %%
units
# Out:
# {'A1': [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9'],
#   ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'I1'],
#   ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3']],
#  'A2': [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9'],
#   ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2', 'I2'],
#   ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3']],
#  'A3': [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9'],
#   ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3', 'I3'],
#   ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3']],
#  'A4': [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9'],
#   ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4', 'I4'],
#   ['A4', 'A5', 'A6', 'B4', 'B5', 'B6', 'C4', 'C5', 'C6']],
#  'A5': [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9'],
#   ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5', 'I5'],
#   ['A4', 'A5', 'A6', 'B4', 'B5', 'B6', 'C4', 'C5', 'C6']],
#  'A6': [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9'],
#   ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6', 'I6'],
#   ['A4', 'A5', 'A6', 'B4', 'B5', 'B6', 'C4', 'C5', 'C6']],
#  'A7': [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9'],
#   ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7', 'I7'],
#   ['A7', 'A8', 'A9', 'B7', 'B8', 'B9', 'C7', 'C8', 'C9']],
#  'A8': [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9'],
#   ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8', 'I8'],
#   ['A7', 'A8', 'A9', 'B7', 'B8', 'B9', 'C7', 'C8', 'C9']],
#  'A9': [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9'],
#   ['A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9', 'I9'],
#   ['A7', 'A8', 'A9', 'B7', 'B8', 'B9', 'C7', 'C8', 'C9']],
#  'B1': [['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9'],
#   ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'I1'],
#   ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3']],
#  'B2': [['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9'],
#   ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2', 'I2'],
#   ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3']],
#  'B3': [['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9'],
#   ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3', 'I3'],
#   ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3']],
#  'B4': [['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9'],
#   ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4', 'I4'],
#   ['A4', 'A5', 'A6', 'B4', 'B5', 'B6', 'C4', 'C5', 'C6']],
#  'B5': [['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9'],
#   ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5', 'I5'],
#   ['A4', 'A5', 'A6', 'B4', 'B5', 'B6', 'C4', 'C5', 'C6']],
#  'B6': [['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9'],
#   ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6', 'I6'],
#   ['A4', 'A5', 'A6', 'B4', 'B5', 'B6', 'C4', 'C5', 'C6']],
#  'B7': [['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9'],
#   ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7', 'I7'],
#   ['A7', 'A8', 'A9', 'B7', 'B8', 'B9', 'C7', 'C8', 'C9']],
#  'B8': [['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9'],
#   ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8', 'I8'],
#   ['A7', 'A8', 'A9', 'B7', 'B8', 'B9', 'C7', 'C8', 'C9']],
#  'B9': [['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9'],
#   ['A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9', 'I9'],
#   ['A7', 'A8', 'A9', 'B7', 'B8', 'B9', 'C7', 'C8', 'C9']],
#  'C1': [['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'],
#   ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'I1'],
#   ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3']],
#  'C2': [['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'],
#   ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2', 'I2'],
#   ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3']],
#  'C3': [['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'],
#   ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3', 'I3'],
#   ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3']],
#  'C4': [['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'],
#   ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4', 'I4'],
#   ['A4', 'A5', 'A6', 'B4', 'B5', 'B6', 'C4', 'C5', 'C6']],
#  'C5': [['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'],
#   ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5', 'I5'],
#   ['A4', 'A5', 'A6', 'B4', 'B5', 'B6', 'C4', 'C5', 'C6']],
#  'C6': [['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'],
#   ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6', 'I6'],
#   ['A4', 'A5', 'A6', 'B4', 'B5', 'B6', 'C4', 'C5', 'C6']],
#  'C7': [['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'],
#   ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7', 'I7'],
#   ['A7', 'A8', 'A9', 'B7', 'B8', 'B9', 'C7', 'C8', 'C9']],
#  'C8': [['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'],
#   ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8', 'I8'],
#   ['A7', 'A8', 'A9', 'B7', 'B8', 'B9', 'C7', 'C8', 'C9']],
#  'C9': [['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'],
#   ['A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9', 'I9'],
#   ['A7', 'A8', 'A9', 'B7', 'B8', 'B9', 'C7', 'C8', 'C9']],
#  'D1': [['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9'],
#   ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'I1'],
#   ['D1', 'D2', 'D3', 'E1', 'E2', 'E3', 'F1', 'F2', 'F3']],
#  'D2': [['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9'],
#   ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2', 'I2'],
#   ['D1', 'D2', 'D3', 'E1', 'E2', 'E3', 'F1', 'F2', 'F3']],
#  'D3': [['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9'],
#   ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3', 'I3'],
#   ['D1', 'D2', 'D3', 'E1', 'E2', 'E3', 'F1', 'F2', 'F3']],
#  'D4': [['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9'],
#   ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4', 'I4'],
#   ['D4', 'D5', 'D6', 'E4', 'E5', 'E6', 'F4', 'F5', 'F6']],
#  'D5': [['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9'],
#   ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5', 'I5'],
#   ['D4', 'D5', 'D6', 'E4', 'E5', 'E6', 'F4', 'F5', 'F6']],
#  'D6': [['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9'],
#   ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6', 'I6'],
#   ['D4', 'D5', 'D6', 'E4', 'E5', 'E6', 'F4', 'F5', 'F6']],
#  'D7': [['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9'],
#   ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7', 'I7'],
#   ['D7', 'D8', 'D9', 'E7', 'E8', 'E9', 'F7', 'F8', 'F9']],
#  'D8': [['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9'],
#   ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8', 'I8'],
#   ['D7', 'D8', 'D9', 'E7', 'E8', 'E9', 'F7', 'F8', 'F9']],
#  'D9': [['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9'],
#   ['A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9', 'I9'],
#   ['D7', 'D8', 'D9', 'E7', 'E8', 'E9', 'F7', 'F8', 'F9']],
#  'E1': [['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9'],
#   ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'I1'],
#   ['D1', 'D2', 'D3', 'E1', 'E2', 'E3', 'F1', 'F2', 'F3']],
#  'E2': [['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9'],
#   ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2', 'I2'],
#   ['D1', 'D2', 'D3', 'E1', 'E2', 'E3', 'F1', 'F2', 'F3']],
#  'E3': [['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9'],
#   ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3', 'I3'],
#   ['D1', 'D2', 'D3', 'E1', 'E2', 'E3', 'F1', 'F2', 'F3']],
#  'E4': [['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9'],
#   ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4', 'I4'],
#   ['D4', 'D5', 'D6', 'E4', 'E5', 'E6', 'F4', 'F5', 'F6']],
#  'E5': [['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9'],
#   ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5', 'I5'],
#   ['D4', 'D5', 'D6', 'E4', 'E5', 'E6', 'F4', 'F5', 'F6']],
#  'E6': [['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9'],
#   ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6', 'I6'],
#   ['D4', 'D5', 'D6', 'E4', 'E5', 'E6', 'F4', 'F5', 'F6']],
#  'E7': [['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9'],
#   ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7', 'I7'],
#   ['D7', 'D8', 'D9', 'E7', 'E8', 'E9', 'F7', 'F8', 'F9']],
#  'E8': [['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9'],
#   ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8', 'I8'],
#   ['D7', 'D8', 'D9', 'E7', 'E8', 'E9', 'F7', 'F8', 'F9']],
#  'E9': [['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9'],
#   ['A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9', 'I9'],
#   ['D7', 'D8', 'D9', 'E7', 'E8', 'E9', 'F7', 'F8', 'F9']],
#  'F1': [['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9'],
#   ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'I1'],
#   ['D1', 'D2', 'D3', 'E1', 'E2', 'E3', 'F1', 'F2', 'F3']],
#  'F2': [['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9'],
#   ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2', 'I2'],
#   ['D1', 'D2', 'D3', 'E1', 'E2', 'E3', 'F1', 'F2', 'F3']],
#  'F3': [['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9'],
#   ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3', 'I3'],
#   ['D1', 'D2', 'D3', 'E1', 'E2', 'E3', 'F1', 'F2', 'F3']],
#  'F4': [['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9'],
#   ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4', 'I4'],
#   ['D4', 'D5', 'D6', 'E4', 'E5', 'E6', 'F4', 'F5', 'F6']],
#  'F5': [['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9'],
#   ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5', 'I5'],
#   ['D4', 'D5', 'D6', 'E4', 'E5', 'E6', 'F4', 'F5', 'F6']],
#  'F6': [['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9'],
#   ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6', 'I6'],
#   ['D4', 'D5', 'D6', 'E4', 'E5', 'E6', 'F4', 'F5', 'F6']],
#  'F7': [['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9'],
#   ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7', 'I7'],
#   ['D7', 'D8', 'D9', 'E7', 'E8', 'E9', 'F7', 'F8', 'F9']],
#  'F8': [['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9'],
#   ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8', 'I8'],
#   ['D7', 'D8', 'D9', 'E7', 'E8', 'E9', 'F7', 'F8', 'F9']],
#  'F9': [['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9'],
#   ['A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9', 'I9'],
#   ['D7', 'D8', 'D9', 'E7', 'E8', 'E9', 'F7', 'F8', 'F9']],
#  'G1': [['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9'],
#   ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'I1'],
#   ['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3']],
#  'G2': [['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9'],
#   ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2', 'I2'],
#   ['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3']],
#  'G3': [['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9'],
#   ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3', 'I3'],
#   ['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3']],
#  'G4': [['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9'],
#   ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4', 'I4'],
#   ['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6']],
#  'G5': [['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9'],
#   ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5', 'I5'],
#   ['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6']],
#  'G6': [['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9'],
#   ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6', 'I6'],
#   ['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6']],
#  'G7': [['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9'],
#   ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7', 'I7'],
#   ['G7', 'G8', 'G9', 'H7', 'H8', 'H9', 'I7', 'I8', 'I9']],
#  'G8': [['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9'],
#   ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8', 'I8'],
#   ['G7', 'G8', 'G9', 'H7', 'H8', 'H9', 'I7', 'I8', 'I9']],
#  'G9': [['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9'],
#   ['A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9', 'I9'],
#   ['G7', 'G8', 'G9', 'H7', 'H8', 'H9', 'I7', 'I8', 'I9']],
#  'H1': [['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9'],
#   ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'I1'],
#   ['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3']],
#  'H2': [['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9'],
#   ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2', 'I2'],
#   ['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3']],
#  'H3': [['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9'],
#   ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3', 'I3'],
#   ['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3']],
#  'H4': [['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9'],
#   ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4', 'I4'],
#   ['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6']],
#  'H5': [['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9'],
#   ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5', 'I5'],
#   ['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6']],
#  'H6': [['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9'],
#   ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6', 'I6'],
#   ['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6']],
#  'H7': [['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9'],
#   ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7', 'I7'],
#   ['G7', 'G8', 'G9', 'H7', 'H8', 'H9', 'I7', 'I8', 'I9']],
#  'H8': [['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9'],
#   ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8', 'I8'],
#   ['G7', 'G8', 'G9', 'H7', 'H8', 'H9', 'I7', 'I8', 'I9']],
#  'H9': [['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9'],
#   ['A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9', 'I9'],
#   ['G7', 'G8', 'G9', 'H7', 'H8', 'H9', 'I7', 'I8', 'I9']],
#  'I1': [['I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'],
#   ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'I1'],
#   ['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3']],
#  'I2': [['I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'],
#   ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2', 'I2'],
#   ['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3']],
#  'I3': [['I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'],
#   ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3', 'I3'],
#   ['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3']],
#  'I4': [['I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'],
#   ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4', 'I4'],
#   ['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6']],
#  'I5': [['I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'],
#   ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5', 'I5'],
#   ['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6']],
#  'I6': [['I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'],
#   ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6', 'I6'],
#   ['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6']],
#  'I7': [['I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'],
#   ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7', 'I7'],
#   ['G7', 'G8', 'G9', 'H7', 'H8', 'H9', 'I7', 'I8', 'I9']],
#  'I8': [['I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'],
#   ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8', 'I8'],
#   ['G7', 'G8', 'G9', 'H7', 'H8', 'H9', 'I7', 'I8', 'I9']],
#  'I9': [['I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'],
#   ['A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9', 'I9'],
#   ['G7', 'G8', 'G9', 'H7', 'H8', 'H9', 'I7', 'I8', 'I9']]}

# %%
peers
# Out:
# {'A1': {'A2',
#   'A3',
#   'A4',
#   'A5',
#   'A6',
#   'A7',
#   'A8',
#   'A9',
#   'B1',
#   'B2',
#   'B3',
#   'C1',
#   'C2',
#   'C3',
#   'D1',
#   'E1',
#   'F1',
#   'G1',
#   'H1',
#   'I1'},
#  'A2': {'A1',
#   'A3',
#   'A4',
#   'A5',
#   'A6',
#   'A7',
#   'A8',
#   'A9',
#   'B1',
#   'B2',
#   'B3',
#   'C1',
#   'C2',
#   'C3',
#   'D2',
#   'E2',
#   'F2',
#   'G2',
#   'H2',
#   'I2'},
#  'A3': {'A1',
#   'A2',
#   'A4',
#   'A5',
#   'A6',
#   'A7',
#   'A8',
#   'A9',
#   'B1',
#   'B2',
#   'B3',
#   'C1',
#   'C2',
#   'C3',
#   'D3',
#   'E3',
#   'F3',
#   'G3',
#   'H3',
#   'I3'},
#  'A4': {'A1',
#   'A2',
#   'A3',
#   'A5',
#   'A6',
#   'A7',
#   'A8',
#   'A9',
#   'B4',
#   'B5',
#   'B6',
#   'C4',
#   'C5',
#   'C6',
#   'D4',
#   'E4',
#   'F4',
#   'G4',
#   'H4',
#   'I4'},
#  'A5': {'A1',
#   'A2',
#   'A3',
#   'A4',
#   'A6',
#   'A7',
#   'A8',
#   'A9',
#   'B4',
#   'B5',
#   'B6',
#   'C4',
#   'C5',
#   'C6',
#   'D5',
#   'E5',
#   'F5',
#   'G5',
#   'H5',
#   'I5'},
#  'A6': {'A1',
#   'A2',
#   'A3',
#   'A4',
#   'A5',
#   'A7',
#   'A8',
#   'A9',
#   'B4',
#   'B5',
#   'B6',
#   'C4',
#   'C5',
#   'C6',
#   'D6',
#   'E6',
#   'F6',
#   'G6',
#   'H6',
#   'I6'},
#  'A7': {'A1',
#   'A2',
#   'A3',
#   'A4',
#   'A5',
#   'A6',
#   'A8',
#   'A9',
#   'B7',
#   'B8',
#   'B9',
#   'C7',
#   'C8',
#   'C9',
#   'D7',
#   'E7',
#   'F7',
#   'G7',
#   'H7',
#   'I7'},
#  'A8': {'A1',
#   'A2',
#   'A3',
#   'A4',
#   'A5',
#   'A6',
#   'A7',
#   'A9',
#   'B7',
#   'B8',
#   'B9',
#   'C7',
#   'C8',
#   'C9',
#   'D8',
#   'E8',
#   'F8',
#   'G8',
#   'H8',
#   'I8'},
#  'A9': {'A1',
#   'A2',
#   'A3',
#   'A4',
#   'A5',
#   'A6',
#   'A7',
#   'A8',
#   'B7',
#   'B8',
#   'B9',
#   'C7',
#   'C8',
#   'C9',
#   'D9',
#   'E9',
#   'F9',
#   'G9',
#   'H9',
#   'I9'},
#  'B1': {'A1',
#   'A2',
#   'A3',
#   'B2',
#   'B3',
#   'B4',
#   'B5',
#   'B6',
#   'B7',
#   'B8',
#   'B9',
#   'C1',
#   'C2',
#   'C3',
#   'D1',
#   'E1',
#   'F1',
#   'G1',
#   'H1',
#   'I1'},
#  'B2': {'A1',
#   'A2',
#   'A3',
#   'B1',
#   'B3',
#   'B4',
#   'B5',
#   'B6',
#   'B7',
#   'B8',
#   'B9',
#   'C1',
#   'C2',
#   'C3',
#   'D2',
#   'E2',
#   'F2',
#   'G2',
#   'H2',
#   'I2'},
#  'B3': {'A1',
#   'A2',
#   'A3',
#   'B1',
#   'B2',
#   'B4',
#   'B5',
#   'B6',
#   'B7',
#   'B8',
#   'B9',
#   'C1',
#   'C2',
#   'C3',
#   'D3',
#   'E3',
#   'F3',
#   'G3',
#   'H3',
#   'I3'},
#  'B4': {'A4',
#   'A5',
#   'A6',
#   'B1',
#   'B2',
#   'B3',
#   'B5',
#   'B6',
#   'B7',
#   'B8',
#   'B9',
#   'C4',
#   'C5',
#   'C6',
#   'D4',
#   'E4',
#   'F4',
#   'G4',
#   'H4',
#   'I4'},
#  'B5': {'A4',
#   'A5',
#   'A6',
#   'B1',
#   'B2',
#   'B3',
#   'B4',
#   'B6',
#   'B7',
#   'B8',
#   'B9',
#   'C4',
#   'C5',
#   'C6',
#   'D5',
#   'E5',
#   'F5',
#   'G5',
#   'H5',
#   'I5'},
#  'B6': {'A4',
#   'A5',
#   'A6',
#   'B1',
#   'B2',
#   'B3',
#   'B4',
#   'B5',
#   'B7',
#   'B8',
#   'B9',
#   'C4',
#   'C5',
#   'C6',
#   'D6',
#   'E6',
#   'F6',
#   'G6',
#   'H6',
#   'I6'},
#  'B7': {'A7',
#   'A8',
#   'A9',
#   'B1',
#   'B2',
#   'B3',
#   'B4',
#   'B5',
#   'B6',
#   'B8',
#   'B9',
#   'C7',
#   'C8',
#   'C9',
#   'D7',
#   'E7',
#   'F7',
#   'G7',
#   'H7',
#   'I7'},
#  'B8': {'A7',
#   'A8',
#   'A9',
#   'B1',
#   'B2',
#   'B3',
#   'B4',
#   'B5',
#   'B6',
#   'B7',
#   'B9',
#   'C7',
#   'C8',
#   'C9',
#   'D8',
#   'E8',
#   'F8',
#   'G8',
#   'H8',
#   'I8'},
#  'B9': {'A7',
#   'A8',
#   'A9',
#   'B1',
#   'B2',
#   'B3',
#   'B4',
#   'B5',
#   'B6',
#   'B7',
#   'B8',
#   'C7',
#   'C8',
#   'C9',
#   'D9',
#   'E9',
#   'F9',
#   'G9',
#   'H9',
#   'I9'},
#  'C1': {'A1',
#   'A2',
#   'A3',
#   'B1',
#   'B2',
#   'B3',
#   'C2',
#   'C3',
#   'C4',
#   'C5',
#   'C6',
#   'C7',
#   'C8',
#   'C9',
#   'D1',
#   'E1',
#   'F1',
#   'G1',
#   'H1',
#   'I1'},
#  'C2': {'A1',
#   'A2',
#   'A3',
#   'B1',
#   'B2',
#   'B3',
#   'C1',
#   'C3',
#   'C4',
#   'C5',
#   'C6',
#   'C7',
#   'C8',
#   'C9',
#   'D2',
#   'E2',
#   'F2',
#   'G2',
#   'H2',
#   'I2'},
#  'C3': {'A1',
#   'A2',
#   'A3',
#   'B1',
#   'B2',
#   'B3',
#   'C1',
#   'C2',
#   'C4',
#   'C5',
#   'C6',
#   'C7',
#   'C8',
#   'C9',
#   'D3',
#   'E3',
#   'F3',
#   'G3',
#   'H3',
#   'I3'},
#  'C4': {'A4',
#   'A5',
#   'A6',
#   'B4',
#   'B5',
#   'B6',
#   'C1',
#   'C2',
#   'C3',
#   'C5',
#   'C6',
#   'C7',
#   'C8',
#   'C9',
#   'D4',
#   'E4',
#   'F4',
#   'G4',
#   'H4',
#   'I4'},
#  'C5': {'A4',
#   'A5',
#   'A6',
#   'B4',
#   'B5',
#   'B6',
#   'C1',
#   'C2',
#   'C3',
#   'C4',
#   'C6',
#   'C7',
#   'C8',
#   'C9',
#   'D5',
#   'E5',
#   'F5',
#   'G5',
#   'H5',
#   'I5'},
#  'C6': {'A4',
#   'A5',
#   'A6',
#   'B4',
#   'B5',
#   'B6',
#   'C1',
#   'C2',
#   'C3',
#   'C4',
#   'C5',
#   'C7',
#   'C8',
#   'C9',
#   'D6',
#   'E6',
#   'F6',
#   'G6',
#   'H6',
#   'I6'},
#  'C7': {'A7',
#   'A8',
#   'A9',
#   'B7',
#   'B8',
#   'B9',
#   'C1',
#   'C2',
#   'C3',
#   'C4',
#   'C5',
#   'C6',
#   'C8',
#   'C9',
#   'D7',
#   'E7',
#   'F7',
#   'G7',
#   'H7',
#   'I7'},
#  'C8': {'A7',
#   'A8',
#   'A9',
#   'B7',
#   'B8',
#   'B9',
#   'C1',
#   'C2',
#   'C3',
#   'C4',
#   'C5',
#   'C6',
#   'C7',
#   'C9',
#   'D8',
#   'E8',
#   'F8',
#   'G8',
#   'H8',
#   'I8'},
#  'C9': {'A7',
#   'A8',
#   'A9',
#   'B7',
#   'B8',
#   'B9',
#   'C1',
#   'C2',
#   'C3',
#   'C4',
#   'C5',
#   'C6',
#   'C7',
#   'C8',
#   'D9',
#   'E9',
#   'F9',
#   'G9',
#   'H9',
#   'I9'},
#  'D1': {'A1',
#   'B1',
#   'C1',
#   'D2',
#   'D3',
#   'D4',
#   'D5',
#   'D6',
#   'D7',
#   'D8',
#   'D9',
#   'E1',
#   'E2',
#   'E3',
#   'F1',
#   'F2',
#   'F3',
#   'G1',
#   'H1',
#   'I1'},
#  'D2': {'A2',
#   'B2',
#   'C2',
#   'D1',
#   'D3',
#   'D4',
#   'D5',
#   'D6',
#   'D7',
#   'D8',
#   'D9',
#   'E1',
#   'E2',
#   'E3',
#   'F1',
#   'F2',
#   'F3',
#   'G2',
#   'H2',
#   'I2'},
#  'D3': {'A3',
#   'B3',
#   'C3',
#   'D1',
#   'D2',
#   'D4',
#   'D5',
#   'D6',
#   'D7',
#   'D8',
#   'D9',
#   'E1',
#   'E2',
#   'E3',
#   'F1',
#   'F2',
#   'F3',
#   'G3',
#   'H3',
#   'I3'},
#  'D4': {'A4',
#   'B4',
#   'C4',
#   'D1',
#   'D2',
#   'D3',
#   'D5',
#   'D6',
#   'D7',
#   'D8',
#   'D9',
#   'E4',
#   'E5',
#   'E6',
#   'F4',
#   'F5',
#   'F6',
#   'G4',
#   'H4',
#   'I4'},
#  'D5': {'A5',
#   'B5',
#   'C5',
#   'D1',
#   'D2',
#   'D3',
#   'D4',
#   'D6',
#   'D7',
#   'D8',
#   'D9',
#   'E4',
#   'E5',
#   'E6',
#   'F4',
#   'F5',
#   'F6',
#   'G5',
#   'H5',
#   'I5'},
#  'D6': {'A6',
#   'B6',
#   'C6',
#   'D1',
#   'D2',
#   'D3',
#   'D4',
#   'D5',
#   'D7',
#   'D8',
#   'D9',
#   'E4',
#   'E5',
#   'E6',
#   'F4',
#   'F5',
#   'F6',
#   'G6',
#   'H6',
#   'I6'},
#  'D7': {'A7',
#   'B7',
#   'C7',
#   'D1',
#   'D2',
#   'D3',
#   'D4',
#   'D5',
#   'D6',
#   'D8',
#   'D9',
#   'E7',
#   'E8',
#   'E9',
#   'F7',
#   'F8',
#   'F9',
#   'G7',
#   'H7',
#   'I7'},
#  'D8': {'A8',
#   'B8',
#   'C8',
#   'D1',
#   'D2',
#   'D3',
#   'D4',
#   'D5',
#   'D6',
#   'D7',
#   'D9',
#   'E7',
#   'E8',
#   'E9',
#   'F7',
#   'F8',
#   'F9',
#   'G8',
#   'H8',
#   'I8'},
#  'D9': {'A9',
#   'B9',
#   'C9',
#   'D1',
#   'D2',
#   'D3',
#   'D4',
#   'D5',
#   'D6',
#   'D7',
#   'D8',
#   'E7',
#   'E8',
#   'E9',
#   'F7',
#   'F8',
#   'F9',
#   'G9',
#   'H9',
#   'I9'},
#  'E1': {'A1',
#   'B1',
#   'C1',
#   'D1',
#   'D2',
#   'D3',
#   'E2',
#   'E3',
#   'E4',
#   'E5',
#   'E6',
#   'E7',
#   'E8',
#   'E9',
#   'F1',
#   'F2',
#   'F3',
#   'G1',
#   'H1',
#   'I1'},
#  'E2': {'A2',
#   'B2',
#   'C2',
#   'D1',
#   'D2',
#   'D3',
#   'E1',
#   'E3',
#   'E4',
#   'E5',
#   'E6',
#   'E7',
#   'E8',
#   'E9',
#   'F1',
#   'F2',
#   'F3',
#   'G2',
#   'H2',
#   'I2'},
#  'E3': {'A3',
#   'B3',
#   'C3',
#   'D1',
#   'D2',
#   'D3',
#   'E1',
#   'E2',
#   'E4',
#   'E5',
#   'E6',
#   'E7',
#   'E8',
#   'E9',
#   'F1',
#   'F2',
#   'F3',
#   'G3',
#   'H3',
#   'I3'},
#  'E4': {'A4',
#   'B4',
#   'C4',
#   'D4',
#   'D5',
#   'D6',
#   'E1',
#   'E2',
#   'E3',
#   'E5',
#   'E6',
#   'E7',
#   'E8',
#   'E9',
#   'F4',
#   'F5',
#   'F6',
#   'G4',
#   'H4',
#   'I4'},
#  'E5': {'A5',
#   'B5',
#   'C5',
#   'D4',
#   'D5',
#   'D6',
#   'E1',
#   'E2',
#   'E3',
#   'E4',
#   'E6',
#   'E7',
#   'E8',
#   'E9',
#   'F4',
#   'F5',
#   'F6',
#   'G5',
#   'H5',
#   'I5'},
#  'E6': {'A6',
#   'B6',
#   'C6',
#   'D4',
#   'D5',
#   'D6',
#   'E1',
#   'E2',
#   'E3',
#   'E4',
#   'E5',
#   'E7',
#   'E8',
#   'E9',
#   'F4',
#   'F5',
#   'F6',
#   'G6',
#   'H6',
#   'I6'},
#  'E7': {'A7',
#   'B7',
#   'C7',
#   'D7',
#   'D8',
#   'D9',
#   'E1',
#   'E2',
#   'E3',
#   'E4',
#   'E5',
#   'E6',
#   'E8',
#   'E9',
#   'F7',
#   'F8',
#   'F9',
#   'G7',
#   'H7',
#   'I7'},
#  'E8': {'A8',
#   'B8',
#   'C8',
#   'D7',
#   'D8',
#   'D9',
#   'E1',
#   'E2',
#   'E3',
#   'E4',
#   'E5',
#   'E6',
#   'E7',
#   'E9',
#   'F7',
#   'F8',
#   'F9',
#   'G8',
#   'H8',
#   'I8'},
#  'E9': {'A9',
#   'B9',
#   'C9',
#   'D7',
#   'D8',
#   'D9',
#   'E1',
#   'E2',
#   'E3',
#   'E4',
#   'E5',
#   'E6',
#   'E7',
#   'E8',
#   'F7',
#   'F8',
#   'F9',
#   'G9',
#   'H9',
#   'I9'},
#  'F1': {'A1',
#   'B1',
#   'C1',
#   'D1',
#   'D2',
#   'D3',
#   'E1',
#   'E2',
#   'E3',
#   'F2',
#   'F3',
#   'F4',
#   'F5',
#   'F6',
#   'F7',
#   'F8',
#   'F9',
#   'G1',
#   'H1',
#   'I1'},
#  'F2': {'A2',
#   'B2',
#   'C2',
#   'D1',
#   'D2',
#   'D3',
#   'E1',
#   'E2',
#   'E3',
#   'F1',
#   'F3',
#   'F4',
#   'F5',
#   'F6',
#   'F7',
#   'F8',
#   'F9',
#   'G2',
#   'H2',
#   'I2'},
#  'F3': {'A3',
#   'B3',
#   'C3',
#   'D1',
#   'D2',
#   'D3',
#   'E1',
#   'E2',
#   'E3',
#   'F1',
#   'F2',
#   'F4',
#   'F5',
#   'F6',
#   'F7',
#   'F8',
#   'F9',
#   'G3',
#   'H3',
#   'I3'},
#  'F4': {'A4',
#   'B4',
#   'C4',
#   'D4',
#   'D5',
#   'D6',
#   'E4',
#   'E5',
#   'E6',
#   'F1',
#   'F2',
#   'F3',
#   'F5',
#   'F6',
#   'F7',
#   'F8',
#   'F9',
#   'G4',
#   'H4',
#   'I4'},
#  'F5': {'A5',
#   'B5',
#   'C5',
#   'D4',
#   'D5',
#   'D6',
#   'E4',
#   'E5',
#   'E6',
#   'F1',
#   'F2',
#   'F3',
#   'F4',
#   'F6',
#   'F7',
#   'F8',
#   'F9',
#   'G5',
#   'H5',
#   'I5'},
#  'F6': {'A6',
#   'B6',
#   'C6',
#   'D4',
#   'D5',
#   'D6',
#   'E4',
#   'E5',
#   'E6',
#   'F1',
#   'F2',
#   'F3',
#   'F4',
#   'F5',
#   'F7',
#   'F8',
#   'F9',
#   'G6',
#   'H6',
#   'I6'},
#  'F7': {'A7',
#   'B7',
#   'C7',
#   'D7',
#   'D8',
#   'D9',
#   'E7',
#   'E8',
#   'E9',
#   'F1',
#   'F2',
#   'F3',
#   'F4',
#   'F5',
#   'F6',
#   'F8',
#   'F9',
#   'G7',
#   'H7',
#   'I7'},
#  'F8': {'A8',
#   'B8',
#   'C8',
#   'D7',
#   'D8',
#   'D9',
#   'E7',
#   'E8',
#   'E9',
#   'F1',
#   'F2',
#   'F3',
#   'F4',
#   'F5',
#   'F6',
#   'F7',
#   'F9',
#   'G8',
#   'H8',
#   'I8'},
#  'F9': {'A9',
#   'B9',
#   'C9',
#   'D7',
#   'D8',
#   'D9',
#   'E7',
#   'E8',
#   'E9',
#   'F1',
#   'F2',
#   'F3',
#   'F4',
#   'F5',
#   'F6',
#   'F7',
#   'F8',
#   'G9',
#   'H9',
#   'I9'},
#  'G1': {'A1',
#   'B1',
#   'C1',
#   'D1',
#   'E1',
#   'F1',
#   'G2',
#   'G3',
#   'G4',
#   'G5',
#   'G6',
#   'G7',
#   'G8',
#   'G9',
#   'H1',
#   'H2',
#   'H3',
#   'I1',
#   'I2',
#   'I3'},
#  'G2': {'A2',
#   'B2',
#   'C2',
#   'D2',
#   'E2',
#   'F2',
#   'G1',
#   'G3',
#   'G4',
#   'G5',
#   'G6',
#   'G7',
#   'G8',
#   'G9',
#   'H1',
#   'H2',
#   'H3',
#   'I1',
#   'I2',
#   'I3'},
#  'G3': {'A3',
#   'B3',
#   'C3',
#   'D3',
#   'E3',
#   'F3',
#   'G1',
#   'G2',
#   'G4',
#   'G5',
#   'G6',
#   'G7',
#   'G8',
#   'G9',
#   'H1',
#   'H2',
#   'H3',
#   'I1',
#   'I2',
#   'I3'},
#  'G4': {'A4',
#   'B4',
#   'C4',
#   'D4',
#   'E4',
#   'F4',
#   'G1',
#   'G2',
#   'G3',
#   'G5',
#   'G6',
#   'G7',
#   'G8',
#   'G9',
#   'H4',
#   'H5',
#   'H6',
#   'I4',
#   'I5',
#   'I6'},
#  'G5': {'A5',
#   'B5',
#   'C5',
#   'D5',
#   'E5',
#   'F5',
#   'G1',
#   'G2',
#   'G3',
#   'G4',
#   'G6',
#   'G7',
#   'G8',
#   'G9',
#   'H4',
#   'H5',
#   'H6',
#   'I4',
#   'I5',
#   'I6'},
#  'G6': {'A6',
#   'B6',
#   'C6',
#   'D6',
#   'E6',
#   'F6',
#   'G1',
#   'G2',
#   'G3',
#   'G4',
#   'G5',
#   'G7',
#   'G8',
#   'G9',
#   'H4',
#   'H5',
#   'H6',
#   'I4',
#   'I5',
#   'I6'},
#  'G7': {'A7',
#   'B7',
#   'C7',
#   'D7',
#   'E7',
#   'F7',
#   'G1',
#   'G2',
#   'G3',
#   'G4',
#   'G5',
#   'G6',
#   'G8',
#   'G9',
#   'H7',
#   'H8',
#   'H9',
#   'I7',
#   'I8',
#   'I9'},
#  'G8': {'A8',
#   'B8',
#   'C8',
#   'D8',
#   'E8',
#   'F8',
#   'G1',
#   'G2',
#   'G3',
#   'G4',
#   'G5',
#   'G6',
#   'G7',
#   'G9',
#   'H7',
#   'H8',
#   'H9',
#   'I7',
#   'I8',
#   'I9'},
#  'G9': {'A9',
#   'B9',
#   'C9',
#   'D9',
#   'E9',
#   'F9',
#   'G1',
#   'G2',
#   'G3',
#   'G4',
#   'G5',
#   'G6',
#   'G7',
#   'G8',
#   'H7',
#   'H8',
#   'H9',
#   'I7',
#   'I8',
#   'I9'},
#  'H1': {'A1',
#   'B1',
#   'C1',
#   'D1',
#   'E1',
#   'F1',
#   'G1',
#   'G2',
#   'G3',
#   'H2',
#   'H3',
#   'H4',
#   'H5',
#   'H6',
#   'H7',
#   'H8',
#   'H9',
#   'I1',
#   'I2',
#   'I3'},
#  'H2': {'A2',
#   'B2',
#   'C2',
#   'D2',
#   'E2',
#   'F2',
#   'G1',
#   'G2',
#   'G3',
#   'H1',
#   'H3',
#   'H4',
#   'H5',
#   'H6',
#   'H7',
#   'H8',
#   'H9',
#   'I1',
#   'I2',
#   'I3'},
#  'H3': {'A3',
#   'B3',
#   'C3',
#   'D3',
#   'E3',
#   'F3',
#   'G1',
#   'G2',
#   'G3',
#   'H1',
#   'H2',
#   'H4',
#   'H5',
#   'H6',
#   'H7',
#   'H8',
#   'H9',
#   'I1',
#   'I2',
#   'I3'},
#  'H4': {'A4',
#   'B4',
#   'C4',
#   'D4',
#   'E4',
#   'F4',
#   'G4',
#   'G5',
#   'G6',
#   'H1',
#   'H2',
#   'H3',
#   'H5',
#   'H6',
#   'H7',
#   'H8',
#   'H9',
#   'I4',
#   'I5',
#   'I6'},
#  'H5': {'A5',
#   'B5',
#   'C5',
#   'D5',
#   'E5',
#   'F5',
#   'G4',
#   'G5',
#   'G6',
#   'H1',
#   'H2',
#   'H3',
#   'H4',
#   'H6',
#   'H7',
#   'H8',
#   'H9',
#   'I4',
#   'I5',
#   'I6'},
#  'H6': {'A6',
#   'B6',
#   'C6',
#   'D6',
#   'E6',
#   'F6',
#   'G4',
#   'G5',
#   'G6',
#   'H1',
#   'H2',
#   'H3',
#   'H4',
#   'H5',
#   'H7',
#   'H8',
#   'H9',
#   'I4',
#   'I5',
#   'I6'},
#  'H7': {'A7',
#   'B7',
#   'C7',
#   'D7',
#   'E7',
#   'F7',
#   'G7',
#   'G8',
#   'G9',
#   'H1',
#   'H2',
#   'H3',
#   'H4',
#   'H5',
#   'H6',
#   'H8',
#   'H9',
#   'I7',
#   'I8',
#   'I9'},
#  'H8': {'A8',
#   'B8',
#   'C8',
#   'D8',
#   'E8',
#   'F8',
#   'G7',
#   'G8',
#   'G9',
#   'H1',
#   'H2',
#   'H3',
#   'H4',
#   'H5',
#   'H6',
#   'H7',
#   'H9',
#   'I7',
#   'I8',
#   'I9'},
#  'H9': {'A9',
#   'B9',
#   'C9',
#   'D9',
#   'E9',
#   'F9',
#   'G7',
#   'G8',
#   'G9',
#   'H1',
#   'H2',
#   'H3',
#   'H4',
#   'H5',
#   'H6',
#   'H7',
#   'H8',
#   'I7',
#   'I8',
#   'I9'},
#  'I1': {'A1',
#   'B1',
#   'C1',
#   'D1',
#   'E1',
#   'F1',
#   'G1',
#   'G2',
#   'G3',
#   'H1',
#   'H2',
#   'H3',
#   'I2',
#   'I3',
#   'I4',
#   'I5',
#   'I6',
#   'I7',
#   'I8',
#   'I9'},
#  'I2': {'A2',
#   'B2',
#   'C2',
#   'D2',
#   'E2',
#   'F2',
#   'G1',
#   'G2',
#   'G3',
#   'H1',
#   'H2',
#   'H3',
#   'I1',
#   'I3',
#   'I4',
#   'I5',
#   'I6',
#   'I7',
#   'I8',
#   'I9'},
#  'I3': {'A3',
#   'B3',
#   'C3',
#   'D3',
#   'E3',
#   'F3',
#   'G1',
#   'G2',
#   'G3',
#   'H1',
#   'H2',
#   'H3',
#   'I1',
#   'I2',
#   'I4',
#   'I5',
#   'I6',
#   'I7',
#   'I8',
#   'I9'},
#  'I4': {'A4',
#   'B4',
#   'C4',
#   'D4',
#   'E4',
#   'F4',
#   'G4',
#   'G5',
#   'G6',
#   'H4',
#   'H5',
#   'H6',
#   'I1',
#   'I2',
#   'I3',
#   'I5',
#   'I6',
#   'I7',
#   'I8',
#   'I9'},
#  'I5': {'A5',
#   'B5',
#   'C5',
#   'D5',
#   'E5',
#   'F5',
#   'G4',
#   'G5',
#   'G6',
#   'H4',
#   'H5',
#   'H6',
#   'I1',
#   'I2',
#   'I3',
#   'I4',
#   'I6',
#   'I7',
#   'I8',
#   'I9'},
#  'I6': {'A6',
#   'B6',
#   'C6',
#   'D6',
#   'E6',
#   'F6',
#   'G4',
#   'G5',
#   'G6',
#   'H4',
#   'H5',
#   'H6',
#   'I1',
#   'I2',
#   'I3',
#   'I4',
#   'I5',
#   'I7',
#   'I8',
#   'I9'},
#  'I7': {'A7',
#   'B7',
#   'C7',
#   'D7',
#   'E7',
#   'F7',
#   'G7',
#   'G8',
#   'G9',
#   'H7',
#   'H8',
#   'H9',
#   'I1',
#   'I2',
#   'I3',
#   'I4',
#   'I5',
#   'I6',
#   'I8',
#   'I9'},
#  'I8': {'A8',
#   'B8',
#   'C8',
#   'D8',
#   'E8',
#   'F8',
#   'G7',
#   'G8',
#   'G9',
#   'H7',
#   'H8',
#   'H9',
#   'I1',
#   'I2',
#   'I3',
#   'I4',
#   'I5',
#   'I6',
#   'I7',
#   'I9'},
#  'I9': {'A9',
#   'B9',
#   'C9',
#   'D9',
#   'E9',
#   'F9',
#   'G7',
#   'G8',
#   'G9',
#   'H7',
#   'H8',
#   'H9',
#   'I1',
#   'I2',
#   'I3',
#   'I4',
#   'I5',
#   'I6',
#   'I7',
#   'I8'}}

# %%
def grid_values(grid):
    """
    Convert grid into a dict of {square: char} with '123456789' for empties.
    Input: A grid in string form.
    Output: A grid in dictionary form
            Keys: The boxes, e.g., 'A1'
            Values: The value in each box, e.g., '8'. If the box has no value, then the value will be '123456789'.
    """
    chars = []
    digits = '123456789'
    for c in grid:
        if c in digits:
            chars.append(c)
        if c == '.':
            chars.append(digits)
    assert len(chars) == 81
    return dict(zip(boxes, chars))

# %%
def eliminate(values):
    """Apply the eliminate strategy to a Sudoku puzzle

    The eliminate strategy says that if a box has a value assigned, then none
    of the peers of that box can have the same value.

    Parameters
    ----------
    values(dict)
        a dictionary of the form {'box_name': '123456789', ...}

    Returns
    -------
    dict
        The values dictionary with the assigned values eliminated from peers
    """
    
    solved_values = [box for box in values.keys() if len(values[box]) == 1]
    for box in solved_values:
        digit = values[box]
        for peer in peers[box]:
            values[peer] = values[peer].replace(digit,'')
    return values

# %%
def only_choice(values):
    """Apply the only choice strategy to a Sudoku puzzle

    The only choice strategy says that if only one box in a unit allows a certain
    digit, then that box must be assigned that digit.

    Parameters
    ----------
    values(dict)
        a dictionary of the form {'box_name': '123456789', ...}

    Returns
    -------
    dict
        The values dictionary with all single-valued boxes assigned

    """
    
    for unit in unitlist:
        for digit in '123456789':
            dplaces = [box for box in unit if digit in values[box]]
            if len(dplaces) == 1:
                values[dplaces[0]] = digit
    return values

# %%
def naked_twins(values):
    """Eliminate values using the naked twins strategy.

    The naked twins strategy says that if you have two or more unallocated boxes
    in a unit and there are only two digits that can go in those two boxes, then
    those two digits can be eliminated from the possible assignments of all other
    boxes in the same unit.

    Parameters
    ----------
    values(dict)
        a dictionary of the form {'box_name': '123456789', ...}

    Returns
    -------
    dict
        The values dictionary with the naked twins eliminated from peers
    """

    for box_a in values:
        for box_b in peers[box_a]:
            if values[box_a]==values[box_b] and len(values[box_a])==2:
                for common_peer in set(list(peers[box_a])+list(peers[box_b]))-set([box_a,box_b]):
                    for digit in values[box_a]:
                        values[common_peer] = values[common_peer].replace(digit,'')
    return values

# %%
def reduce_puzzle(values):
    """Reduce a Sudoku puzzle by repeatedly applying all constraint strategies

    Parameters
    ----------
    values(dict)
        a dictionary of the form {'box_name': '123456789', ...}

    Returns
    -------
    dict or False
        The values dictionary after continued application of the constraint strategies
        no longer produces any changes, or False if the puzzle is unsolvable
    """
    
    stalled = False
    while not stalled:
        # Check how many boxes have a determined value
        solved_values_before = len([box for box in values.keys() if len(values[box]) == 1])
        # Use the Eliminate Strategy
        values = eliminate(values)
        # Use the Only Choice Strategy
        values = only_choice(values)
        # Use the Naked Twins Strategy
        #values = naked_twins(values)
        # Check how many boxes have a determined value, to compare
        solved_values_after = len([box for box in values.keys() if len(values[box]) == 1])
        # If no new values were added, stop the loop.
        stalled = solved_values_before == solved_values_after
        # Sanity check, return False if there is a box with zero available values:
        if len([box for box in values.keys() if len(values[box]) == 0]):
            return False
    return values

# %%
def search(values):
    """Apply depth first search to solve Sudoku puzzles in order to solve puzzles
    that cannot be solved by repeated reduction alone.

    Parameters
    ----------
    values(dict)
        a dictionary of the form {'box_name': '123456789', ...}

    Returns
    -------
    dict or False
        The values dictionary with all boxes assigned or False

    """

    # First, reduce the puzzle using the previous function
    values = reduce_puzzle(values)
    if values is False:
        return False ## Failed earlier
    if all(len(values[s]) == 1 for s in boxes):
        return values ## Solved!
    # Choose one of the unfilled squares with the fewest possibilities
    n,s = min((len(values[s]), s) for s in boxes if len(values[s]) > 1)
    # recurrence to solve each one of the resulting sudokus
    for value in values[s]:
        print("trying ",value," for position ",s)
        new_sudoku = values.copy()
        new_sudoku[s] = value
        attempt = search(new_sudoku)
        if attempt:
            print("returning attempt")
            return attempt

# %%
def solve(grid):
    """Find the solution to a Sudoku puzzle using search and constraint propagation

    Parameters
    ----------
    grid(string)
        a string representing a sudoku grid.

    Returns
    -------
    dict or False
        The dictionary representation of the final sudoku grid or False if no solution exists.
    """
    values = grid_values(grid)
    values = search(values)
    return values

# %%
result = solve(grid)
result
# Out:
# trying  8  for position  G2
# trying  2  for position  G1
# trying  4  for position  G5
# trying  6  for position  H2
# trying  1  for position  A2
# trying  3  for position  A4
# trying  2  for position  A8
# trying  6  for position  A5
# trying  9  for position  A5
# trying  9  for position  A8
# trying  2  for position  A5
# trying  5  for position  B5
# trying  9  for position  B5
# trying  6  for position  A5
# trying  5  for position  B5
# trying  9  for position  B5
# trying  9  for position  A4
# trying  2  for position  A6
# trying  6  for position  A6
# trying  2  for position  A5
# trying  3  for position  A5
# trying  2  for position  B5
# trying  5  for position  B5
# trying  9  for position  A2
# trying  1  for position  A4
# trying  2  for position  A6
# trying  6  for position  B1
# trying  5  for position  B5
# trying  9  for position  B5
# trying  8  for position  B1
# trying  5  for position  B5
# trying  9  for position  B5
# trying  6  for position  A6
# trying  2  for position  A5
# trying  6  for position  B1
# trying  8  for position  B1
# trying  3  for position  A5
# trying  6  for position  B1
# trying  8  for position  B1
# trying  3  for position  A4
# trying  2  for position  A5
# trying  6  for position  B1
# trying  8  for position  B1
# trying  6  for position  A5
# trying  6  for position  B1
# trying  2  for position  B3
# trying  5  for position  B3
# trying  8  for position  B1
# trying  2  for position  B3
# trying  5  for position  B3
# trying  7  for position  H2
# trying  1  for position  A2
# trying  3  for position  A4
# returning attempt
# returning attempt
# returning attempt
# returning attempt
# returning attempt
# returning attempt
# {'A1': '4',
#  'A2': '1',
#  'A3': '7',
#  'A4': '3',
#  'A5': '6',
#  'A6': '9',
#  'A7': '8',
#  'A8': '2',
#  'A9': '5',
#  'B1': '6',
#  'B2': '3',
#  'B3': '2',
#  'B4': '1',
#  'B5': '5',
#  'B6': '8',
#  'B7': '9',
#  'B8': '4',
#  'B9': '7',
#  'C1': '9',
#  'C2': '5',
#  'C3': '8',
#  'C4': '7',
#  'C5': '2',
#  'C6': '4',
#  'C7': '3',
#  'C8': '1',
#  'C9': '6',
#  'D1': '8',
#  'D2': '2',
#  'D3': '5',
#  'D4': '4',
#  'D5': '3',
#  'D6': '7',
#  'D7': '1',
#  'D8': '6',
#  'D9': '9',
#  'E1': '7',
#  'E2': '9',
#  'E3': '1',
#  'E4': '5',
#  'E5': '8',
#  'E6': '6',
#  'E7': '4',
#  'E8': '3',
#  'E9': '2',
#  'F1': '3',
#  'F2': '4',
#  'F3': '6',
#  'F4': '9',
#  'F5': '1',
#  'F6': '2',
#  'F7': '7',
#  'F8': '5',
#  'F9': '8',
#  'G1': '2',
#  'G2': '8',
#  'G3': '9',
#  'G4': '6',
#  'G5': '4',
#  'G6': '3',
#  'G7': '5',
#  'G8': '7',
#  'G9': '1',
#  'H1': '5',
#  'H2': '7',
#  'H3': '3',
#  'H4': '2',
#  'H5': '9',
#  'H6': '1',
#  'H7': '6',
#  'H8': '8',
#  'H9': '4',
#  'I1': '1',
#  'I2': '6',
#  'I3': '4',
#  'I4': '8',
#  'I5': '7',
#  'I6': '5',
#  'I7': '2',
#  'I8': '9',
#  'I9': '3'}
